# %% [markdown]
# # 1D Sparse Inversion with real data
#
# Workflow to do Sparse inversion in real line data

# %%
# SimPEG functionality
import simpeg.electromagnetics.frequency_domain as fdem
from simpeg.utils import plot_1d_layer_model, download, mkvc
from simpeg import (
    maps,
    data,
    data_misfit,
    regularization,
    optimization,
    inverse_problem,
    inversion,
    directives,
)

# discretize functionality
from discretize import TensorMesh

# Common Python functionality
import os
import numpy as np
import pandas as pd
from scipy.constants import mu_0
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import ipywidgets
import dill
# %matplotlib inline
mpl.rcParams.update({"font.size": 12})

#Import helper functions
import sys
import data_functions, inversion_functions, l2_inversion, sparse_inversion

# %% [markdown]
# # Read the data:
#
# Read from csv file of block 53:

# %%
# Get the current working directory (where the notebook is running)
current_dir = os.getcwd()

# Move one level up to the parent directory
parent_dir = os.path.dirname(current_dir)

# Construct the full path to the CSV file in the parent directory
csv_path = os.path.join(parent_dir, "block53_fdem_inv.csv")

fdem_data = pd.read_csv(csv_path) ## Set to the position of the csv_files list where the database you want is
pd.set_option('display.max_columns', len(fdem_data.columns))
fdem_data.head()
# Out:
#         x_tx        y_tx  gpsz_tx  altlas_bird  altlas_bird_derot  \
# 0  553008.70  7603566.43   125.52        20.71              20.53
# 1  553006.00  7603565.62   125.40        20.18              20.04
# 2  553003.29  7603564.81   125.28        19.72              19.62
# 3  553000.59  7603564.00   125.16        19.34              19.27
# 4  552997.88  7603563.19   125.04        19.05              19.01
#
#    altrad_heli  bird_pitch  bird_roll  bird_yaw  Block  cp40k_reim  \
# 0        49.56       -0.75      -7.63     253.8   53.0        0.65
# 1        49.26       -0.80      -6.70     253.3   53.0        0.64
# 2        49.00       -0.82      -5.75     252.8   53.0        0.62
# 3        48.76       -0.82      -4.79     252.4   53.0        0.61
# 4        48.54       -0.80      -3.82     252.0   53.0        0.60
#
#    cp140k_reim  cp400_reim  cp1800_reim  cp8200_reim  cpi40k  cpi140k  cpi400  \
# 0         0.99        0.61        0.934        0.834  1127.2   3023.2    86.5
# ...

# %%
# Set Halfspace conductivity:
conductivities_hsp = 0.03422309704591167
resistivities_hsp = 1/conductivities_hsp

# %% [markdown]
# # Inversion Process
#
# Of a single Line:

# %%
# Define like working with:
line_no = 'L530030'
line = fdem_data.loc[fdem_data['Line'] == line_no].copy()

# Calculate the tx_rx coordinates:
line = data_functions.calculate_tx_rx_coordinates(line)

# Get fid values
line_stations = line.fid.values

print(line_stations)
# Out:
# [4148.  4148.1 4148.2 ... 4261.2 4261.3 4261.4]

# %%
#Define the single fid from line
fid_n = 4248.

line_station = line.loc[line.fid == fid_n].iloc[0]

## Calculate the height 

#Calculate the height (terrain clearance)
line_station.loc['height_tx'] = line_station['gpsz_tx'] - line_station['dtm']

# %% [markdown]
# ## Defining the Survey
#
# Same for all soundings:
# RESOLVE 6 system flew by by Xcalibur Multiphysic in August 2024. Nominal frequencies 135 kHz, 40 kHz, 8.2 kHz, 1.8 kHz and 400

# %% [markdown]
# ### Generate source and receivers locations

# %%
freq_avoid = []
survey = inversion_functions.survey_object(line_station, freq_avoid)

# %% [markdown]
# ## Defining Data Object

# %%
# Defines the data object and assigns uncertainties with the noise floor
uncertainty_floor = 5.0e0
relative_error = 0.05 #What is relative error?

data_object = inversion_functions.data_object(line_station, relative_error = relative_error, noise_floor = uncertainty_floor, survey = survey, freq_avoid = freq_avoid)

# %% [markdown]
# # Define Mesh

# %%
### Mesh Definition for l2 inversion ###

### Depth max ###
min_frequency = 400
skin_depth = 503*np.sqrt(resistivities_hsp/np.min(min_frequency))
depth_max = 2*skin_depth  # depth to lowest layer

### Mesh Definition ###

regularization_mesh_Sp, log_conductivity_Sp_map, simulation_Sp, n_layers = inversion_functions.mapping_forward_objects(n_layers = 2, survey = survey, depth_max = depth_max, depth_min = 1, geometric_factor = 1.2)

# %%
# Starting model is log-conductivity values (S/m) from halfspace results
starting_conductivity_model_Sp = np.log(conductivities_hsp * np.ones(n_layers))

# Reference model is also log-resistivity values (S/m)
reference_conductivity_model_Sp = starting_conductivity_model_Sp.copy()

# %% [markdown]
# ## Data Misfit

# %%
dmis_hsp_Sp = data_misfit.L2DataMisfit(simulation=simulation_Sp, data=data_object)

# %% [markdown]
# ## Regularization

# %%
reg_Sp = inversion_functions.regularization_object(regularization_mesh_Sp, reference_conductivity_model = reference_conductivity_model_Sp , alpha_s = 1e-5, alpha_x = 1, sparse_regularization=True, norms = [0,0])

# %% [markdown]
# ## Optimization

# %%
opt_Sp = optimization.InexactGaussNewton(
    maxIter=100, maxIterLS=20, maxIterCG=20, tolCG=1e-3
)

# %% [markdown]
# ## Inversion Parameters

# %%
# Combine the inverse problem and the set of directives
inv_Sp, save_output = inversion_functions.inversion_setup(dmis_hsp_Sp, reg_Sp, opt_Sp, beta_ratio = 1e2,  sparse_inversion=True, IRLS_coolrate=3, IRLS_coolfactor=10, IRLS_percentile=95, save_outputs=True)

# %% [markdown]
# ## Running Inversion

# %%
#%%capture 
#To not show output
recovered_model_Sp = inv_Sp.run(starting_conductivity_model_Sp)

## Get the recovered halfspace resistivity from model estimated
conductivities_Sp = log_conductivity_Sp_map * recovered_model_Sp
resistivities_Sp = 1 / conductivities_Sp

#Simulate data:
dpred_Sp = simulation_Sp.dpred(recovered_model_Sp)
# Out:
# Running inversion with SimPEG v0.23.1.dev1+g60e0c3a5
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation1DLayered problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.41e+04  4.44e+03  1.55e-31  4.44e+03    2.49e+03      0
#    1  1.41e+04  5.81e+02  1.35e-02  7.72e+02    4.88e+02      0
#    2  1.41e+04  3.04e+02  8.01e-03  4.17e+02    8.32e+01      0   Skip BFGS
#    3  1.41e+03  3.05e+02  6.88e-03  3.15e+02    1.03e+02      0   Skip BFGS
#    4  1.41e+03  1.34e+02  5.33e-02  2.09e+02    2.40e+01      0
#    5  1.41e+03  1.12e+02  6.50e-02  2.04e+02    6.28e+00      0   Skip BFGS
# ...

# %%
data_functions.plot_inv_results(regularization_mesh_Sp, conductivities_Sp, dpred_Sp, dobs=data_object.dobs)

# %%
#Plot tikhonov curves:

output_dict = save_output.outDict
# Sort keys to make sure order is correct
iterations = sorted(output_dict.keys())

betas = [output_dict[i]["beta"] for i in iterations]
phi_ds = [output_dict[i]["phi_d"] for i in iterations]
phi_ms = [output_dict[i]["phi_m"] for i in iterations]

target_phid = len(data_object.dobs)

fig, ax = data_functions.plot_tikhonov_curve(betas, phi_ds, phi_ms, phid_star=target_phid, highlight_iter=-1)

# %% [markdown]
# # Running with python files function

# %%
### Calculate max depth ###
min_frequency = 400
skin_depth = 503*np.sqrt(resistivities_hsp/np.min(min_frequency))
depth_max = 2*skin_depth  # depth to lowest layer

regularization_mesh_Sp, log_conductivity_Sp_map, simulation_Sp, inv_Sp, inv_prob, recovered_model_Sp, conductivities_Sp = sparse_inversion.sparse_inversion(line_station, conductivities_hsp, depth_max = depth_max, inv_prob_return = True)
# Out:
# Running inversion with SimPEG v0.23.1.dev1+g60e0c3a5
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation1DLayered problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.39e+04  4.44e+03  1.55e-31  4.44e+03    2.49e+03      0
#    1  1.39e+04  5.80e+02  1.37e-02  7.70e+02    4.86e+02      0
#    2  1.39e+04  3.03e+02  8.14e-03  4.16e+02    8.04e+01      0   Skip BFGS
#    3  1.39e+03  3.04e+02  6.96e-03  3.14e+02    1.02e+02      0   Skip BFGS
#    4  1.39e+03  1.32e+02  5.43e-02  2.07e+02    2.41e+01      0
#    5  1.39e+03  1.10e+02  6.61e-02  2.02e+02    6.26e+00      0   Skip BFGS
# ...

# %%
dpred_Sp = simulation_Sp.dpred(recovered_model_Sp)

data_functions.plot_inv_results(regularization_mesh_Sp, conductivities_Sp, dpred_Sp)

# %% [markdown]
# # Running with single beta value

# %%
# Run inversion with set up single beta value
regularization_mesh_Sp, log_conductivity_Sp_map, simulation_Sp, inv_Sp, inv_prob, recovered_model_Sp, conductivities_Sp = sparse_inversion.sparse_inversion(line_station, conductivities_hsp, depth_max = depth_max, single_beta =1393.6008811061492, inv_prob_return = True)

dpred_Sp = simulation_Sp.dpred(recovered_model_Sp)

data_functions.plot_inv_results(regularization_mesh_Sp, conductivities_Sp, dpred_Sp)

# %%
#> /dev/null

# %% [markdown]
# # ToDos
# * Use paralelizations and GPUs
